# %%
import numpy as np

# %%
# np.linalg.

# %%
import scipy as sp

# %%
A = np.array([[1.0,1.0,-1.0],[3.0,-1.0,1.0],[1.0, -3.0,2.0]])
A
# Out:
# array([[ 1.,  1., -1.],
#        [ 3., -1.,  1.],
#        [ 1., -3.,  2.]])

# %%
b = np.array([[0],[4],[1.1]],dtype=float)
b
# Out:
# array([[0. ],
#        [4. ],
#        [1.1]])

# %%
np.linalg.solve(A,b)
# Out:
# array([[1. ],
#        [1.9],
#        [2.9]])

# %%
C = np.array([[1,1],[1.00001,1]],dtype=float)
d = np.array([2,2.0],dtype=float)

# %%
np.linalg.solve(C,d)
# Out:
# array([0., 2.])

# %%
np.linalg.cond(A,p = np.inf)
# Out:
# np.float64(24.0)

# %%
np.linalg.cond(C,p=np.inf)
# np.linalg.cond(C)
# Out:
# np.float64(400004.000007742)
